# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
# ...

# %%
titanic=pd.read_csv('D:\\PGP IN DATA SCIENCE with careerera\\Files\\titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
type(titanic_survived)
# Out:
# pandas.core.series.Series

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
pd.options.display.max_rows=900

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include='O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
titanic.age
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5        NaN
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17       NaN
# 18     31.00
# 19       NaN
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26       NaN
# 27     19.00
# 28       NaN
# 29       NaN
# 30     40.00
# 31       NaN
# 32       NaN
# 33     66.00
# 34     28.00
# 35     42.00
# 36       NaN
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42       NaN
# 43      3.00
# 44     19.00
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55       NaN
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64       NaN
# 65       NaN
# ...

# %%
titanic['age']
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5        NaN
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17       NaN
# 18     31.00
# 19       NaN
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26       NaN
# 27     19.00
# 28       NaN
# 29       NaN
# 30     40.00
# 31       NaN
# 32       NaN
# 33     66.00
# 34     28.00
# 35     42.00
# 36       NaN
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42       NaN
# 43      3.00
# 44     19.00
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55       NaN
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64       NaN
# 65       NaN
# ...

# %%
import pandas as pd

# %%
titanic=pd.read_csv('D:\\PGP IN DATA SCIENCE\\Files\\titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic_new=titanic[['survived','sex','age']]

# %%
titanic_new
# Out:
#      survived     sex    age
# 0           0    male  22.00
# 1           1  female  38.00
# 2           1  female  26.00
# 3           1  female  35.00
# 4           0    male  35.00
# 5           0    male    NaN
# 6           0    male  54.00
# 7           0    male   2.00
# 8           1  female  27.00
# 9           1  female  14.00
# 10          1  female   4.00
# 11          1  female  58.00
# 12          0    male  20.00
# 13          0    male  39.00
# 14          0  female  14.00
# 15          1  female  55.00
# 16          0    male   2.00
# 17          1    male    NaN
# 18          0  female  31.00
# 19          1  female    NaN
# 20          0    male  35.00
# 21          1    male  34.00
# 22          1  female  15.00
# 23          1    male  28.00
# 24          0  female   8.00
# 25          1  female  38.00
# 26          0    male    NaN
# 27          0    male  19.00
# 28          1  female    NaN
# 29          0    male    NaN
# 30          0    male  40.00
# ...

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic['Total']=titanic['sibsp']+titanic['parch']

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      Total
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# ...

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck', 'Total'],
#       dtype='object')

# %%
titanic.insert(4, 'total', 'sibsp'+'parch')

# %%
titanic
# Out:
#      survived  pclass     sex   age       total  sibsp  parch     fare  \
# 0           0       3    male  22.0  sibspparch      1      0   7.2500
# 1           1       1  female  38.0  sibspparch      1      0  71.2833
# 2           1       3  female  26.0  sibspparch      0      0   7.9250
# 3           1       1  female  35.0  sibspparch      1      0  53.1000
# 4           0       3    male  35.0  sibspparch      0      0   8.0500
# ..        ...     ...     ...   ...         ...    ...    ...      ...
# 886         0       2    male  27.0  sibspparch      0      0  13.0000
# 887         1       1  female  19.0  sibspparch      0      0  30.0000
# 888         0       3  female   NaN  sibspparch      1      2  23.4500
# 889         1       1    male  26.0  sibspparch      0      0  30.0000
# 890         0       3    male  32.0  sibspparch      0      0   7.7500
#
#     embarked deck  Total
# 0          S  NaN      1
# 1          C    C      1
# 2          S  NaN      0
# ...

# %%
titanic.drop(['sibsp','parch'],axis=1,inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age       total     fare embarked deck  Total
# 0           0       3    male  22.0  sibspparch   7.2500        S  NaN      1
# 1           1       1  female  38.0  sibspparch  71.2833        C    C      1
# 2           1       3  female  26.0  sibspparch   7.9250        S  NaN      0
# 3           1       1  female  35.0  sibspparch  53.1000        S    C      1
# 4           0       3    male  35.0  sibspparch   8.0500        S  NaN      0
# ..        ...     ...     ...   ...         ...      ...      ...  ...    ...
# 886         0       2    male  27.0  sibspparch  13.0000        S  NaN      0
# 887         1       1  female  19.0  sibspparch  30.0000        S    B      0
# 888         0       3  female   NaN  sibspparch  23.4500        S  NaN      3
# 889         1       1    male  26.0  sibspparch  30.0000        C    C      0
# 890         0       3    male  32.0  sibspparch   7.7500        Q  NaN      0
#
# [891 rows x 9 columns]

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic['total']=titanic['sibsp']+titanic['parch']

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck  \
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
pd.options.display.max_rows=90

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      total
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# ...

# %%
titanic.drop(['sibsp','parch'],axis=1,inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age     fare embarked deck  total
# 0           0       3    male  22.0   7.2500        S  NaN      1
# 1           1       1  female  38.0  71.2833        C    C      1
# 2           1       3  female  26.0   7.9250        S  NaN      0
# 3           1       1  female  35.0  53.1000        S    C      1
# 4           0       3    male  35.0   8.0500        S  NaN      0
# ..        ...     ...     ...   ...      ...      ...  ...    ...
# 886         0       2    male  27.0  13.0000        S  NaN      0
# 887         1       1  female  19.0  30.0000        S    B      0
# 888         0       3  female   NaN  23.4500        S  NaN      3
# 889         1       1    male  26.0  30.0000        C    C      0
# 890         0       3    male  32.0   7.7500        Q  NaN      0
#
# [891 rows x 8 columns]

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'fare', 'embarked', 'deck',
#        'total'],
#       dtype='object')

# %%
cols=list(titanic.columns)

# %%
cols
# Out:
# ['survived', 'pclass', 'sex', 'age', 'fare', 'embarked', 'deck', 'total']

# %%
cols[0:4]
# Out:
# ['survived', 'pclass', 'sex', 'age']

# %%
cols[-1]
# Out:
# 'total'

# %%
cols[4:7]
# Out:
# ['fare', 'embarked', 'deck']

# %%
titanic_new=titanic[cols[0:4]+[cols[-1]]+cols[4:7]]

# %%
titanic_new
# Out:
#      survived  pclass     sex   age  total     fare embarked deck
# 0           0       3    male  22.0      1   7.2500        S  NaN
# 1           1       1  female  38.0      1  71.2833        C    C
# 2           1       3  female  26.0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1  53.1000        S    C
# 4           0       3    male  35.0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0  30.0000        S    B
# 888         0       3  female   NaN      3  23.4500        S  NaN
# 889         1       1    male  26.0      0  30.0000        C    C
# 890         0       3    male  32.0      0   7.7500        Q  NaN
#
# [891 rows x 8 columns]

# %%
titanic_new.drop(['sex','age'],axis=1,inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
titanic_new
# Out:
#      survived  pclass  total     fare embarked deck
# 0           0       3      1   7.2500        S  NaN
# 1           1       1      1  71.2833        C    C
# 2           1       3      0   7.9250        S  NaN
# 3           1       1      1  53.1000        S    C
# 4           0       3      0   8.0500        S  NaN
# ..        ...     ...    ...      ...      ...  ...
# 886         0       2      0  13.0000        S  NaN
# 887         1       1      0  30.0000        S    B
# 888         0       3      3  23.4500        S  NaN
# 889         1       1      0  30.0000        C    C
# 890         0       3      0   7.7500        Q  NaN
#
# [891 rows x 6 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age     fare embarked deck  total
# 0           0       3    male  22.0   7.2500        S  NaN      1
# 1           1       1  female  38.0  71.2833        C    C      1
# 2           1       3  female  26.0   7.9250        S  NaN      0
# 3           1       1  female  35.0  53.1000        S    C      1
# 4           0       3    male  35.0   8.0500        S  NaN      0
# ..        ...     ...     ...   ...      ...      ...  ...    ...
# 886         0       2    male  27.0  13.0000        S  NaN      0
# 887         1       1  female  19.0  30.0000        S    B      0
# 888         0       3  female   NaN  23.4500        S  NaN      3
# 889         1       1    male  26.0  30.0000        C    C      0
# 890         0       3    male  32.0   7.7500        Q  NaN      0
#
# [891 rows x 8 columns]

# %%
titanic=pd.read_csv('D:\\PGP IN DATA SCIENCE with careerera\\Files\\titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['total']=titanic['sibsp']+titanic['parch']

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      total
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# ...

# %%
titanic.iloc[0:10]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  total
# 0         0       3    male  22.0      1      0   7.2500        S  NaN      1
# 1         1       1  female  38.0      1      0  71.2833        C    C      1
# 2         1       3  female  26.0      0      0   7.9250        S  NaN      0
# 3         1       1  female  35.0      1      0  53.1000        S    C      1
# 4         0       3    male  35.0      0      0   8.0500        S  NaN      0
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN      0
# 6         0       1    male  54.0      0      0  51.8625        S    E      0
# 7         0       3    male   2.0      3      1  21.0750        S  NaN      4
# 8         1       3  female  27.0      0      2  11.1333        S  NaN      2
# 9         1       2  female  14.0      1      0  30.0708        C  NaN      1

# %%
titanic.iloc[0:10,[1,2]]
# Out:
#    pclass     sex
# 0       3    male
# 1       1  female
# 2       3  female
# 3       1  female
# 4       3    male
# 5       3    male
# 6       1    male
# 7       3    male
# 8       3  female
# 9       2  female

# %%
titanic.iloc[:,[1,2]]
# Out:
#      pclass     sex
# 0         3    male
# 1         1  female
# 2         3  female
# 3         1  female
# 4         3    male
# ..      ...     ...
# 886       2    male
# 887       1  female
# 888       3  female
# 889       1    male
# 890       3    male
#
# [891 rows x 2 columns]

# %%
titanic.loc[0:10,['age','sex']]
# Out:
#      age     sex
# 0   22.0    male
# 1   38.0  female
# 2   26.0  female
# 3   35.0  female
# 4   35.0    male
# 5    NaN    male
# 6   54.0    male
# 7    2.0    male
# 8   27.0  female
# 9   14.0  female
# 10   4.0  female

# %%
titanic.iloc[10:20,[1,2]]
# Out:
#     pclass     sex
# 10       3  female
# 11       1  female
# 12       3    male
# 13       3    male
# 14       3  female
# 15       2  female
# 16       3    male
# 17       2    male
# 18       3  female
# 19       3  female

# %%
titanic.loc[10:20,['age','sex']]
# Out:
#      age     sex
# 10   4.0  female
# 11  58.0  female
# 12  20.0    male
# 13  39.0    male
# 14  14.0  female
# 15  55.0  female
# 16   2.0    male
# 17   NaN    male
# 18  31.0  female
# 19   NaN  female
# 20  35.0    male

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['total']=titanic['parch']+titanic['sibsp']

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      total
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# ...

# %%
titanic.rename(columns={'total':'alomng_with_passanger'},inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      alomng_with_passanger
# 0                        1
# 1                        1
# ...

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck', 'alomng_with_passanger'],
#       dtype='object')

# %%
titanic.columns=titanic.columns.str.replace("_"," ")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      alomng with passanger
# 0                        1
# 1                        1
# ...

# %%
sns.barplot( x='sex', y='survived', data=titanic, hue='sex');

# %%
sns.barplot(x='sex', y='survived', hue='pclass', data=titanic);

# %%
sns.barplot(x='sex', y='survived', hue='deck', data=titanic);

# %%
sns.barplot(x='sex', y='age', hue='survived', data=titanic);

# %%
titanic_female=titanic[titanic['sex']=='female']

# %%
titanic_female
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
#      alomng with passanger
# 1                        1
# 2                        0
# ...

# %%
titanic_kid=titanic[titanic['age']<18]

# %%
titanic_kid
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# 10          1       3  female   4.0      1      1  16.7000        S    G
# 14          0       3  female  14.0      0      0   7.8542        S  NaN
# 16          0       3    male   2.0      4      1  29.1250        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 850         0       3    male   4.0      4      2  31.2750        S  NaN
# 852         0       3  female   9.0      1      1  15.2458        C  NaN
# 853         1       1  female  16.0      0      1  39.4000        S    D
# 869         1       3    male   4.0      1      1  11.1333        S  NaN
# 875         1       3  female  15.0      0      0   7.2250        C  NaN
#
#      alomng with passanger
# 7                        4
# 9                        1
# ...

# %%
titanic_male_kid=titanic[(titanic['sex']=='male') & (titanic['age']<18)]

# %%
titanic_male_kid
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck  \
# 7           0       3  male   2.00      3      1   21.0750        S  NaN
# 16          0       3  male   2.00      4      1   29.1250        Q  NaN
# 50          0       3  male   7.00      4      1   39.6875        S  NaN
# 59          0       3  male  11.00      5      2   46.9000        S  NaN
# 63          0       3  male   4.00      3      2   27.9000        S  NaN
# 78          1       2  male   0.83      0      2   29.0000        S  NaN
# 86          0       3  male  16.00      1      3   34.3750        S  NaN
# 125         1       3  male  12.00      1      0   11.2417        C  NaN
# 138         0       3  male  16.00      0      0    9.2167        S  NaN
# 163         0       3  male  17.00      0      0    8.6625        S  NaN
# 164         0       3  male   1.00      4      1   39.6875        S  NaN
# 165         1       3  male   9.00      0      2   20.5250        S  NaN
# ...

# %%
titanic_male_kid.describe()
# Out:
#         survived     pclass        age      sibsp      parch        fare  \
# count  58.000000  58.000000  58.000000  58.000000  58.000000   58.000000
# mean    0.396552   2.672414   8.856379   1.706897   1.068966   29.739729
# std     0.493454   0.603729   6.268262   1.757277   0.791669   27.500510
# min     0.000000   1.000000   0.420000   0.000000   0.000000    7.054200
# 25%     0.000000   2.250000   3.000000   0.000000   0.250000   11.160400
# 50%     0.000000   3.000000   9.000000   1.000000   1.000000   26.000000
# 75%     1.000000   3.000000  16.000000   4.000000   2.000000   36.940650
# max     1.000000   3.000000  17.000000   5.000000   3.000000  151.550000
#
#        alomng with passanger
# count              58.000000
# mean                2.775862
# std                 2.200822
# min                 0.000000
# 25%                 1.000000
# 50%                 2.000000
# 75%                 5.000000
# max                 7.000000

# %%
titanic_female.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  314.000000  314.000000  261.000000  314.000000  314.000000  314.000000
# mean     0.742038    2.159236   27.915709    0.694268    0.649682   44.479818
# std      0.438211    0.857290   14.110146    1.156520    1.022846   57.997698
# min      0.000000    1.000000    0.750000    0.000000    0.000000    6.750000
# 25%      0.000000    1.000000   18.000000    0.000000    0.000000   12.071875
# 50%      1.000000    2.000000   27.000000    0.000000    0.000000   23.000000
# 75%      1.000000    3.000000   37.000000    1.000000    1.000000   55.000000
# max      1.000000    3.000000   63.000000    8.000000    6.000000  512.329200
#
#        alomng with passanger
# count             314.000000
# mean                1.343949
# std                 1.755733
# min                 0.000000
# 25%                 0.000000
# 50%                 1.000000
# 75%                 2.000000
# ...
